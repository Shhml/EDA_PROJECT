# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/bengaluru_house_prices - bengaluru_house_prices.csv")
df
# Out:
#                   area_type   availability                  location  ... bath balcony   price
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  ...  2.0     1.0   39.07
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  ...  5.0     3.0  120.00
# 2            Built-up  Area  Ready To Move               Uttarahalli  ...  2.0     3.0   62.00
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  ...  3.0     1.0   95.00
# 4      Super built-up  Area  Ready To Move                  Kothanur  ...  2.0     1.0   51.00
# ...                     ...            ...                       ...  ...  ...     ...     ...
# 13315        Built-up  Area  Ready To Move                Whitefield  ...  4.0     0.0  231.00
# 13316  Super built-up  Area  Ready To Move             Richards Town  ...  5.0     NaN  400.00
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  ...  2.0     1.0   60.00
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  ...  4.0     1.0  488.00
# 13319  Super built-up  Area  Ready To Move              Doddathoguru  ...  1.0     1.0   17.00
#
# [13320 rows x 9 columns]

# %% [markdown]
# #**`1.Understand the Data`**

# %%
#to print first 5 rows
df.head()
# Out:
#               area_type   availability                  location  ... bath balcony   price
# 0  Super built-up  Area         19-Dec  Electronic City Phase II  ...  2.0     1.0   39.07
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  ...  5.0     3.0  120.00
# 2        Built-up  Area  Ready To Move               Uttarahalli  ...  2.0     3.0   62.00
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli  ...  3.0     1.0   95.00
# 4  Super built-up  Area  Ready To Move                  Kothanur  ...  2.0     1.0   51.00
#
# [5 rows x 9 columns]

# %%
#to print last 5 rows
df.tail()
# Out:
#                   area_type   availability               location  ... bath balcony  price
# 13315        Built-up  Area  Ready To Move             Whitefield  ...  4.0     0.0  231.0
# 13316  Super built-up  Area  Ready To Move          Richards Town  ...  5.0     NaN  400.0
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  ...  2.0     1.0   60.0
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  ...  4.0     1.0  488.0
# 13319  Super built-up  Area  Ready To Move           Doddathoguru  ...  1.0     1.0   17.0
#
# [5 rows x 9 columns]

# %%
#to print a random row
df.sample()
# Out:
#        area_type availability    location       size society total_sqft  bath  balcony  price
# 8620  Plot  Area       18-Jul  Whitefield  3 Bedroom     NaN       1200   3.0      1.0   56.0

# %%
#to print number of columns and rows
df.shape
# Out:
# (13320, 9)

# %%
#to print column names
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
#to print data type
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
#to print null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
#to describe the data set
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
#to describe the object columns
df.describe(include=['object','category'])
# Out:
#                    area_type   availability    location   size  society total_sqft
# count                  13320          13320       13319  13304     7818      13320
# unique                     4             81        1294     31     2688       2117
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr       1200
# freq                    8790          10581         541   5199       80        843

# %%
#to describe all 'float and objects'
df.describe(include="all")
# Out:
#                    area_type   availability    location  ...          bath       balcony         price
# count                  13320          13320       13319  ...  13247.000000  12711.000000  13320.000000
# unique                     4             81        1294  ...           NaN           NaN           NaN
# top     Super built-up  Area  Ready To Move  Whitefield  ...           NaN           NaN           NaN
# freq                    8790          10581         541  ...           NaN           NaN           NaN
# mean                     NaN            NaN         NaN  ...      2.692610      1.584376    112.565627
# std                      NaN            NaN         NaN  ...      1.341458      0.817263    148.971674
# min                      NaN            NaN         NaN  ...      1.000000      0.000000      8.000000
# 25%                      NaN            NaN         NaN  ...      2.000000      1.000000     50.000000
# 50%                      NaN            NaN         NaN  ...      2.000000      2.000000     72.000000
# 75%                      NaN            NaN         NaN  ...      3.000000      2.000000    120.000000
# max                      NaN            NaN         NaN  ...     40.000000      3.000000   3600.000000
#
# [11 rows x 9 columns]

# %%
#to print nunique values
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1294
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: count, dtype: int64

# %% [markdown]
# #**`2.Data Cleaning`**

# %%
#to take a copy of df
df1=df.copy()

# %%
df1.isnull()
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  balcony  price
# 0          False         False     False  False    False       False  False    False  False
# 1          False         False     False  False    False       False  False    False  False
# 2          False         False     False  False     True       False  False    False  False
# 3          False         False     False  False    False       False  False    False  False
# 4          False         False     False  False     True       False  False    False  False
# ...          ...           ...       ...    ...      ...         ...    ...      ...    ...
# 13315      False         False     False  False    False       False  False    False  False
# 13316      False         False     False  False     True       False  False     True  False
# 13317      False         False     False  False    False       False  False    False  False
# 13318      False         False     False  False    False       False  False    False  False
# 13319      False         False     False  False     True       False  False    False  False
#
# [13320 rows x 9 columns]

# %%
#to find the null values in dataset
df1.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
#To drop the column which consisit more null values
df1.drop(columns=['society'],inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
#to find the node
df1['location'].mode()
# Out:
# 0    Whitefield
# Name: location, dtype: object

# %%
#filling null values with mode
df1['location'].fillna(df1['location'].mode()[0],inplace=True)
# Out:
# <ipython-input-315-100d7714f9d6>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['location'].fillna(df1['location'].mode()[0],inplace=True)

# %%
#filling null values with mode (object we use mode())
df1['size'].fillna(df1['size'].mode()[0],inplace=True)
# Out:
# <ipython-input-316-c4dcf66ed757>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['size'].fillna(df1['size'].mode()[0],inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
#to print median of bath column
df1['bath'].median()
# Out:
# 2.0

# %%
df1['bath'].fillna(df1['bath'].median(),inplace=True)
# Out:
# <ipython-input-319-2730037c55a2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['bath'].fillna(df1['bath'].median(),inplace=True)

# %%
df1['balcony'].fillna(df1['balcony'].median(),inplace=True)
# Out:
# <ipython-input-320-90b0c09cd64a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['balcony'].fillna(df1['balcony'].median(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
#differents between df and df1
print(df.shape)
print(df1.shape)
# Out:
# (13320, 9)
# (13320, 8)

# %%
#to know count of duplicates()
df1.duplicated().sum()
# Out:
# 570

# %%
#to remove duplicates
df1.drop_duplicates(inplace=True)

# %%
print(df.shape)
print(df1.shape)
# Out:
# (13320, 9)
# (12750, 8)

# %%
df1['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df1['total_sqft']=df1['total_sqft'].str.extract(r'(\d+\.?\d*)')

# %%
df1['total_sqft']=df1['total_sqft'].astype('float')

# %%
df1['size']=df1['size'].str.extract(r'(\d+\.?\d*)')

# %%
df1['size'].unique()
# Out:
# array(['2', '4', '3', '6', '1', '8', '7', '5', '11', '9', '27', '10',
#        '19', '16', '43', '14', '12', '13', '18'], dtype=object)

# %%
df1['size']=df1['size'].astype('int')

# %%
df1
# Out:
#                   area_type   availability                  location  ...  bath  balcony   price
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  ...   2.0      1.0   39.07
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  ...   5.0      3.0  120.00
# 2            Built-up  Area  Ready To Move               Uttarahalli  ...   2.0      3.0   62.00
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  ...   3.0      1.0   95.00
# 4      Super built-up  Area  Ready To Move                  Kothanur  ...   2.0      1.0   51.00
# ...                     ...            ...                       ...  ...   ...      ...     ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  ...   3.0      3.0  112.00
# 13315        Built-up  Area  Ready To Move                Whitefield  ...   4.0      0.0  231.00
# 13316  Super built-up  Area  Ready To Move             Richards Town  ...   5.0      2.0  400.00
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  ...   2.0      1.0   60.00
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  ...   4.0      1.0  488.00
#
# [12750 rows x 8 columns]

# %%
#to change the data type
df1['bath']=df1['bath'].astype('int')
df1['balcony']=df1['balcony'].astype('int')

# %%
df1.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size              int64
# total_sqft      float64
# bath              int64
# balcony           int64
# price           float64
# dtype: object

# %%
df1.describe()
# Out:
#                size    total_sqft          bath       balcony         price
# count  12750.000000  12750.000000  12750.000000  12750.000000  12750.000000
# mean       2.818510   1563.682786      2.706431      1.602353    114.497392
# std        1.312855   1259.749865      1.356582      0.808513    151.681615
# min        1.000000      1.000000      1.000000      0.000000      8.000000
# 25%        2.000000   1100.000000      2.000000      1.000000     50.000000
# 50%        3.000000   1280.000000      2.000000      2.000000     73.000000
# 75%        3.000000   1690.000000      3.000000      2.000000    122.000000
# max       43.000000  52272.000000     40.000000      3.000000   3600.000000

# %% [markdown]
# #**`3.Data Visualization`**

# %%
#set plot style
sns.set(style="whitegrid")

#distribution plot for numeric columns
fig,axes=plt.subplots(2,2,figsize=(14,10))

#price Distribution
sns.histplot(df1['price'],kde=True,color='blue',ax=axes[0,0])
axes[0,0].set_title('Price Distribution')

#total distribution
sns.histplot(df1['total_sqft'],kde=True,color='green',ax=axes[0,1])
axes[0,1].set_title('total_sqft Distribution')

#bath distribution
sns.histplot(df1['bath'],kde=True,color='orange',ax=axes[1,0])
axes[1,0].set_title('bath Distribution')

#balcony distribution
sns.histplot(df1['balcony'],kde=True,color='red',ax=axes[1,1])
axes[1,1].set_title('balcony Distribution')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#set the plot size for all plots
plt.figure(figsize=(16,12))

#barplot: average price by area type status
plt.subplot(2,2,1)
sns.barplot(x='area_type',y='price',data=df1,palette='Set2')
plt.title('average price by area type status')
plt.xlabel('area_type status')
plt.ylabel('average price')

#barplot: average total sqft by area type status
plt.subplot(2,2,2)
sns.barplot(x='area_type',y='total_sqft',data=df1,palette='Set2')
plt.title('average total sqft by area type status')
plt.xlabel('area_type status')
plt.ylabel('average total sqft')

#barplot: average bath by area type status
plt.subplot(2,2,3)
sns.barplot(x='area_type',y='bath',data=df1,palette='Set2')
plt.title('average bath by area type status')
plt.xlabel('area_type status')
plt.ylabel('average bath')

#barplot: average balcony by area type status
plt.subplot(2,2,4)
sns.barplot(x='area_type',y='balcony',data=df1,palette='Set2')
plt.title('average balcony by area type status')
plt.xlabel('area_type status')
plt.ylabel('average balcony ')

#adjust t he layout to ensure the plots fit nicely
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-337-c239e07475a5>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type',y='price',data=df1,palette='Set2')
# <ipython-input-337-c239e07475a5>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type',y='total_sqft',data=df1,palette='Set2')
# <ipython-input-337-c239e07475a5>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type',y='bath',data=df1,palette='Set2')
# <ipython-input-337-c239e07475a5>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type',y='balcony',data=df1,palette='Set2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#set the plot size for all plots
plt.figure(figsize=(16,12))

#scatter plot: price vs total sqft
plt.subplot(2,2,1)
sns.scatterplot(x='total_sqft',y='price',data=df1,hue='area_type',palette='Set2',alpha=0.6)
plt.title('prive vs total sqft')
plt.xlabel('Total sqrt')
plt.ylabel('price')

#scatter plot: price vs bath
plt.subplot(2,2,2)
sns.scatterplot(x='bath',y='price',data=df1,hue='area_type',palette='Set2',alpha=0.6)
plt.title('prive vs bath')
plt.xlabel('number of bathroom')
plt.ylabel('price')

#scatter plot: price vs balcony
plt.subplot(2,2,3)
sns.scatterplot(x='balcony',y='price',data=df1,hue='area_type',palette='Set2',alpha=0.6)
plt.title('prive vs balcony')
plt.xlabel('number of balcony')
plt.ylabel('price')

#adjust the layout to ensure the plots fit nicely
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#set the plot size for all plots
plt.figure(figsize=(8,10))

#create a subplot grid for 4 plots(2 rows,2columns)
sns.boxplot(x='area_type',y='price',data=df1,palette='Set2')
plt.title('price distribution by area_type ')
plt.xlabel('area type')
plt.ylabel('price')

#adjust the layout to ensure the plots fit nicely
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-339-0a53dafb9546>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type',y='price',data=df1,palette='Set2')

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="area_type",data=df1,palette="Set1")
plt.title("Count of Properties by Area Type")
plt.xlabel("Area Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

#Location is likely to have many unique values,so we can limit the categories shown
plt.figure(figsize=(12,6))
top_locations=df1["location"].value_counts().nlargest(10)  #show top 10 locations
sns.countplot(x="location",data=df1[df1["location"].isin(top_locations.index)],palette="Set2")
plt.title("Count of Properties by Location (Top 10)")
plt.xlabel("Location")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-340-57332326ad30>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="area_type",data=df1,palette="Set1")
# <ipython-input-340-57332326ad30>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="location",data=df1[df1["location"].isin(top_locations.index)],palette="Set2")

# %% [markdown]
# #**`4.outlier Detection and handling`**

# %%
df2=df1.copy()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12750 entries, 0 to 13318
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12750 non-null  object
#  1   availability  12750 non-null  object
#  2   location      12750 non-null  object
#  3   size          12750 non-null  int64
#  4   total_sqft    12750 non-null  float64
#  5   bath          12750 non-null  int64
#  6   balcony       12750 non-null  int64
#  7   price         12750 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 896.5+ KB

# %%
#define a function to calculate IQR outliers
def detect_iqr_outliers(column):
  q1=column.quantile(0.25)
  q3=column.quantile(0.75)
  iqr=q3-q1
  lower_bound=q1-1.5*iqr
  upper_bound=q3+1.5*iqr
  return(column<lower_bound)|(column>upper_bound)

#select only numerical columns
#numerical_cols=df2.select_dtypes(include=["number"]).columns

#Apply the function to numerical columns
outliers_iqr=df2[["size","total_sqft","bath","balcony","price"]].apply(detect_iqr_outliers)

#view outliers
print("Outliers detected using IQR")
print(outliers_iqr.sum())  #Count of outliers per column
# Out:
# Outliers detected using IQR
# size           839
# total_sqft    1164
# bath          1032
# balcony          0
# price         1214
# dtype: int64

# %%
#filter out the rows with any outliers
df2=df2[~(outliers_iqr.any(axis=1))]
print("Data after removing outliers (IQR):")
print(df2)
# Out:
# Data after removing outliers (IQR):
#                   area_type   availability                  location  ...  bath  balcony   price
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  ...     2        1   39.07
# 2            Built-up  Area  Ready To Move               Uttarahalli  ...     2        3   62.00
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  ...     3        1   95.00
# 4      Super built-up  Area  Ready To Move                  Kothanur  ...     2        1   51.00
# 5      Super built-up  Area  Ready To Move                Whitefield  ...     2        1   38.00
# ...                     ...            ...                       ...  ...   ...      ...     ...
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur  ...     3        2   92.13
# 13310  Super built-up  Area  Ready To Move              Rachenahalli  ...     2        2   52.71
# 13312  Super built-up  Area  Ready To Move                 Bellandur  ...     2        2   47.00
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  ...     3        3  112.00
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  ...     2        1   60.00
#
# [10572 rows x 8 columns]

# %%
#set the plot size for all plots
plt.figure(figsize=(8,10))

#create a boxplot
sns.boxplot(x="area_type",y="price",data=df2,palette="Set2")
plt.title("Price Distribution by area_type status")
plt.xlabel("area_type status")
plt.ylabel("price")

#Adjust the layout to ensure the plots fit nicely
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-344-91dcdf0493d1>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="area_type",y="price",data=df2,palette="Set2")

# %%
from scipy.stats import zscore

#compute z-scores
z_scores=df2[["size","total_sqft","bath","balcony","price"]].apply(zscore)

#Define threshold
threshold=3

#identify outliers
outliers_z=(z_scores.abs()>threshold)

#view outliers
print("Outliers detected using z-Score:")
print(outliers_z.sum())   #count of outliers per column
# Out:
# Outliers detected using z-Score:
# size            0
# total_sqft     60
# bath            0
# balcony         0
# price         174
# dtype: int64

# %%
print(df.shape)
print(df1.shape)
print(df2.shape)
# Out:
# (13320, 9)
# (12750, 8)
# (10572, 8)

# %% [markdown]
# #**`5.Feature engineering`**

# %%
df3=df2.copy()

# %%
df3["availability"].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-Feb', '18-Nov', '18-May', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '18-Apr',
#        '20-Aug', '19-Mar', '17-Sep', '18-Dec', '17-Aug', '19-Apr',
#        '18-Jun', '22-Dec', '22-Jan', '18-Aug', '19-Jan', '17-Jul',
#        '18-Jul', '21-Jun', '19-Aug', '18-Sep', '17-Jun', '18-Oct',
#        '21-May', '18-Jan', '20-Mar', '17-Dec', '16-Mar', '19-Jun',
#        '22-Jun', '17-May', '19-Jul', '21-Feb', 'Immediate Possession',
#        '19-May', '20-Oct', '20-Jun', '19-Feb', '21-Oct', '21-Jan',
#        '17-Mar', '17-Nov', '17-Apr', '19-Oct', '21-Jul', '21-Nov',
#        '21-Mar', '16-Dec', '22-Mar', '20-Jan', '21-Sep', '21-Aug',
#        '22-May', '14-Nov', '19-Nov', '15-Nov', '16-Jul', '15-Jun',
#        '20-May', '20-Nov', '20-Jul', '16-Sep', '15-Oct', '20-Feb',
#        '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan', '16-Nov',
#        '20-Apr', '16-Jan', '17-Feb', '14-Jul'], dtype=object)

# %%
import numpy as np

# %%
df3["availability_status"]=np.where(df3["availability"]=="Ready To Move","Immediately available","Available Later")
df3.drop(columns=["availability"],inplace=True)

# %%
df3["availability_status"].value_counts()
# Out:
# availability_status
# Immediately available    8249
# Available Later          2323
# Name: count, dtype: int64

# %% [markdown]
# ##**`Feature Transformation`**

# %%
skewness=df3[["size","total_sqft","bath","balcony","price"]].skew()
print(skewness)
# Out:
# size          0.126922
# total_sqft    0.488706
# bath          0.572381
# balcony       0.023651
# price         1.311559
# dtype: float64

# %%
skewness=df1[["size","total_sqft","bath","balcony","price"]].skew()
print(skewness)
# Out:
# size           4.798069
# total_sqft    15.074480
# bath           4.210266
# balcony       -0.057359
# price          7.944878
# dtype: float64

# %%
for col in ["size","total_sqft","bath","balcony","price"]:
  sns.histplot(df3[col],kde=True)
  plt.title(f"Distribution of {col}")
  plt.show()

# %%
#log tranformation for "price"
df3["price_log"]=np.log1p(df3["price"])  #log1p handles zero and large values safely

#square root transformation for "price"
df3["price_sqrt"]=np.sqrt(df3["price"])

#Display the results
print(df3[["price","price_log","price_sqrt"]])
# Out:
#         price  price_log  price_sqrt
# 0       39.07   3.690628    6.250600
# 2       62.00   4.143135    7.874008
# 3       95.00   4.564348    9.746794
# 4       51.00   3.951244    7.141428
# 5       38.00   3.663562    6.164414
# ...       ...        ...         ...
# 13309   92.13   4.533996    9.598437
# 13310   52.71   3.983599    7.260165
# 13312   47.00   3.871201    6.855655
# 13314  112.00   4.727388   10.583005
# 13317   60.00   4.110874    7.745967
#
# [10572 rows x 3 columns]

# %%
skewness=df3[["price","price_log","price_sqrt"]].skew()
print(skewness)
# Out:
# price         1.311559
# price_log    -0.031509
# price_sqrt    0.671556
# dtype: float64

# %%
df3.drop(columns=["price_sqrt","price_log"],inplace=True)

# %% [markdown]
# ##**`Encoding`**

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10572 entries, 0 to 13317
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   area_type            10572 non-null  object
#  1   location             10572 non-null  object
#  2   size                 10572 non-null  int64
#  3   total_sqft           10572 non-null  float64
#  4   bath                 10572 non-null  int64
#  5   balcony              10572 non-null  int64
#  6   price                10572 non-null  float64
#  7   availability_status  10572 non-null  object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 743.3+ KB

# %%
df3.nunique()
# Out:
# area_type                 4
# location               1102
# size                      4
# total_sqft             1445
# bath                      4
# balcony                   4
# price                  1701
# availability_status       2
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
df3["location"]=le.fit_transform(df3["location"])

df3["location"].dtype
# Out:
# dtype('int64')

# %%
#Now you can access the classes_ attribute from "le"
location_labels=dict(zip(le.classes_,range(len(le.classes_))))
print(location_labels)
# Out:
# {'12th cross srinivas nagar banshankari 3rd stage': 0, '1st Block BEL Layout': 1, '1st Block HBR Layout': 2, '1st Block HRBR Layout': 3, '1st Block Jayanagar': 4, '1st Block Koramangala': 5, '1st Phase JP Nagar': 6, '1st Stage Domlur': 7, '1st Stage Indira Nagar': 8, '2nd Block Bel Layout': 9, '2nd Block Hrbr Layout': 10, '2nd Block Jayanagar': 11, '2nd Phase JP Nagar': 12, '2nd Phase Judicial Layout': 13, '2nd Stage Arekere Mico Layout': 14, '2nd Stage Nagarbhavi': 15, '2nd phase jp nagar, jp nagar': 16, '3rd Block Banashankari': 17, '3rd Block HBR Layout': 18, '3rd Block Hrbr Layout': 19, '3rd Block Jayanagar': 20, '3rd Block Koramangala': 21, '3rd Phase Iti Layout': 22, '3rd Phase JP Nagar': 23, '3rd Stage Raja Rajeshwari Nagar': 24, '4th Block Jayanagar': 25, '4th Block Koramangala': 26, '4th Phase JP Nagar': 27, '4th T block Jayanagar': 28, '5th Block Hbr Layout': 29, '5th Block Jayanagar': 30, '5th Phase JP Nagar': 31, '5th Stage BEML Layout': 32, '6th Phase JP Nagar': 33, '6th block Koramangala': 34, '7th Block Jayanagar': 35, '7th Phase JP Nagar': 36, '8th Block Jayanagar': 37, '8th Phase JP Nagar': 38, '8th block Koramangala': 39, '9th Block Jayanagar': 40, '9th Phase JP Nagar': 41, 'A Narayanapura': 42, 'AECS Layout': 43, 'AGS Layout': 44, 'AMS Layout': 45, 'Aavalahalli': 46, 'Abbaiah Reddy Layout': 47, 'Abbigere': 48, 'Abshot Layout': 49, 'Adarsh Nagar': 50, 'Addischetan Layout': 51, 'Adityanagar': 52, 'Adugodi': 53, 'Agara Village': 54, 'Agrahara Dasarahalli': 55, 'Air View Colony': 56, 'Aishwarya Crystal Layout': 57, 'Akash Nagar': 58, 'Akshaya Nagar': 59, 'Akshaya Vana': 60, 'Akshayanagara East': 61, 'Akshayanagara West': 62, 'Akshya Nagar': 63, 'Alfa Garden Layout': 64, 'Allalasandra': 65, 'Alur': 66, 'Amam Enclave Layout': 67, 'Amarjyothi Colony': 68, 'Ambalipura': 69, 'Ambedkar Colony': 70, 'Ambedkar Nagar': 71, 'Amblipura': 72, 'Amco Colony': 73, 'Amruthahalli': 74, 'Amruthnagar': 75, 'Anand Nagar': 76, 'Anand nagar': 77, 'Anandapura': 78, 'Anantapura': 79, 'Anantapuram': 80, 'Ananth Nagar': 81, 'Ananthanagar Phase 1,Electronic City , phase 2': 82, 'Ananthapura, T C palaya Main Road': 83, 'Anathanagar': 84, 'Andrahalli': 85, 'Anekal': 86, 'Anjana Nagar': 87, 'Anjanapura': 88, 'Anjappa Layout': 89, 'Ankappa Layout': 90, 'Annaiah Reddy Layout': 91, 'Annapoorneshwari Layout, JP nagar 7th phase': 92, 'Annapurneshwari Nagar': 93, 'Anugrah Layout': 94, 'Anwar Layout': 95, 'Ardendale': 96, 'Arehalli': 97, 'Arekempanahalli': 98, 'Arekere': 99, 'Arishinakunte': 100, 'Ashirvad Colony': 101, 'Ashok Nagar': 102, 'Ashwath Nagar': 103, 'Ashwathnagar': 104, 'Ashwini layout': 105, 'Asthagrama Layout': 106, 'Atmananda Colony': 107, 'Attibele': 108, 'Attiguppe': 109, 'Attur Layout': 110, 'Austin Town': 111, 'Avalahalli': 112, 'Ayappa Nagar': 113, 'B Channasandra': 114, 'B Narayanapura': 115, 'B Y Raveshwara Nagar': 116, 'BAGUR': 117, 'BAGUR ROAD': 118, 'BCC Layout': 119, 'BCMC Layout': 120, 'BDS Layout': 121, 'BEL Layout': 122, 'BEL Road': 123, 'BEML Layout': 124, 'BEML Layout 5th stage': 125, 'BHEL Layout': 126, 'BSM Extension': 127, 'BTM 1st Stage': 128, 'BTM 2nd Stage': 129, 'BTM 4th Stage': 130, 'BTM Layout': 131, 'Baba Nagar': 132, 'Babusapalaya': 133, 'Badavala Nagar': 134, 'Badrappa Layout': 135, 'Bagalakunte': 136, 'Bagalur': 137, 'Bagalur Main Road': 138, 'Balagere': 139, 'Balaji Gardens Layout': 140, 'Banagiri Nagar': 141, 'Banagirinagar': 142, 'Banasawadi, ': 143, 'Banashankari': 144, 'Banashankari 2 nd Stage': 145, 'Banashankari 3rd stage, Vivekanandanagar': 146, 'Banashankari 6th Stage': 147, 'Banashankari 6th Stage ,Subramanyapura': 148, 'Banashankari 6th stage , 2nd block': 149, 'Banashankari Stage II': 150, 'Banashankari Stage III': 151, 'Banashankari Stage V': 152, 'Banashankari Stage VI': 153, 'Banashankari stage 2': 154, 'Banashankari3rd stage bigbazar': 155, 'Banaswadi': 156, 'Bande Nallasandra': 157, 'Bandepalya': 158, 'Banjara Layout': 159, 'Bank Avenue': 160, 'Bank Of Baroda Colony': 161, 'Bannerghatta': ...

# %%
df3["availability_status"].unique()
# Out:
# array(['Available Later', 'Immediately available'], dtype=object)

# %%
one_hot_encoded=pd.get_dummies(df3["availability_status"],prefix="one_hot",dtype=int)
df3=pd.concat([df3,one_hot_encoded],axis=1)

# %%
df3["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Built-up  Area', 'Plot  Area',
#        'Carpet  Area'], dtype=object)

# %%
df3["area_type"]=df3["area_type"].map({'Carpet  Area':0,'Plot  Area':1,'Built-up  Area':2,'Super built-up  Area':3})
df3
# Out:
#        area_type  location  ...  one_hot_Available Later  one_hot_Immediately available
# 0              3       342  ...                        1                              0
# 2              2       997  ...                        0                              1
# 3              3       639  ...                        0                              1
# 4              3       605  ...                        0                              1
# 5              3      1058  ...                        0                              1
# ...          ...       ...  ...                      ...                            ...
# 13309          3      1071  ...                        0                              1
# 13310          3       808  ...                        0                              1
# 13312          3       181  ...                        0                              1
# 13314          3       390  ...                        0                              1
# 13317          2       815  ...                        0                              1
#
# [10572 rows x 10 columns]

# %%
df3.drop(columns=["availability_status"],inplace=True)

# %%
df3
# Out:
#        area_type  location  size  ...   price  one_hot_Available Later  one_hot_Immediately available
# 0              3       342     2  ...   39.07                        1                              0
# 2              2       997     3  ...   62.00                        0                              1
# 3              3       639     3  ...   95.00                        0                              1
# 4              3       605     2  ...   51.00                        0                              1
# 5              3      1058     2  ...   38.00                        0                              1
# ...          ...       ...   ...  ...     ...                      ...                            ...
# 13309          3      1071     3  ...   92.13                        0                              1
# 13310          3       808     2  ...   52.71                        0                              1
# 13312          3       181     2  ...   47.00                        0                              1
# 13314          3       390     3  ...  112.00                        0                              1
# 13317          2       815     2  ...   60.00                        0                              1
#
# [10572 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.heatmap(df3.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
df3.drop(columns=["one_hot_Available Later","one_hot_Immediately available","balcony","location","area_type"],inplace=True)

# %%
df3
# Out:
#        size  total_sqft  bath   price
# 0         2      1056.0     2   39.07
# 2         3      1440.0     2   62.00
# 3         3      1521.0     3   95.00
# 4         2      1200.0     2   51.00
# 5         2      1170.0     2   38.00
# ...     ...         ...   ...     ...
# 13309     3      1675.0     3   92.13
# 13310     2      1050.0     2   52.71
# 13312     2      1262.0     2   47.00
# 13314     3      1715.0     3  112.00
# 13317     2      1141.0     2   60.00
#
# [10572 rows x 4 columns]

# %% [markdown]
# #**`Data Scaling`**

# %% [markdown]
# ## `Minmaxscaler`

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler=MinMaxScaler()

df_minmax_scaled=minmax_scaler.fit_transform(df3)

# %%
df_minmax_scaled
# Out:
# array([[0.33333333, 0.34756361, 0.33333333, 0.13995495],
#        [0.66666667, 0.51315222, 0.33333333, 0.24324324],
#        [0.66666667, 0.54808107, 0.66666667, 0.39189189],
#        ...,
#        [0.33333333, 0.436395  , 0.33333333, 0.17567568],
#        [0.66666667, 0.63173782, 0.66666667, 0.46846847],
#        [0.33333333, 0.38421734, 0.33333333, 0.23423423]])

# %%
df_minmax_scaled=pd.DataFrame(df_minmax_scaled,columns=df3.columns)
df_minmax_scaled
# Out:
#            size  total_sqft      bath     price
# 0      0.333333    0.347564  0.333333  0.139955
# 1      0.666667    0.513152  0.333333  0.243243
# 2      0.666667    0.548081  0.666667  0.391892
# 3      0.333333    0.409659  0.333333  0.193694
# 4      0.333333    0.396723  0.333333  0.135135
# ...         ...         ...       ...       ...
# 10567  0.666667    0.614489  0.666667  0.378964
# 10568  0.333333    0.344976  0.333333  0.201396
# 10569  0.333333    0.436395  0.333333  0.175676
# 10570  0.666667    0.631738  0.666667  0.468468
# 10571  0.333333    0.384217  0.333333  0.234234
#
# [10572 rows x 4 columns]

# %%
#create subplot
plt.figure(figsize=(12,10))

#original and scaled data histogram for each feature
plt.subplot(5,2,1)
sns.histplot(df3['size'],kde=True)
plt.title('original: size')

plt.subplot(5,2,2)
sns.histplot(df_minmax_scaled['size'],kde=True)
plt.title('scaled: size')

plt.subplot(5,2,3)
sns.histplot(df3['total_sqft'],kde=True)
plt.title('original: total_sqft')

plt.subplot(5,2,4)
sns.histplot(df_minmax_scaled['total_sqft'],kde=True)
plt.title('scaled: total_sqft')

plt.subplot(5,2,5)
sns.histplot(df3['bath'],kde=True)
plt.title('original: bath')

plt.subplot(5,2,6)
sns.histplot(df_minmax_scaled['bath'],kde=True)
plt.title('scaled: bath')

plt.subplot(5,2,7)
sns.histplot(df3['price'],kde=True)
plt.title('original: price')

plt.subplot(5,2,8)
sns.histplot(df_minmax_scaled['price'],kde=True)
plt.title('scaled: price')
# Out:
# Text(0.5, 1.0, 'scaled: price')

# %% [markdown]
# ##**`Standard scaler`**

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler=StandardScaler()

df_standardized=standard_scaler.fit_transform(df3)

# %%
df_standardized
# Out:
# array([[-0.6486547 , -0.62481539, -0.44344017, -0.90401526],
#        [ 0.8235603 ,  0.37470976, -0.44344017, -0.32167831],
#        [ 0.8235603 ,  0.58554709,  1.0490939 ,  0.51639928],
#        ...,
#        [-0.6486547 , -0.0886118 , -0.44344017, -0.70262268],
#        [ 0.8235603 ,  1.09051553,  1.0490939 ,  0.94813623],
#        [-0.6486547 , -0.40356633, -0.44344017, -0.3724709 ]])

# %%
df_standardized=pd.DataFrame(df_standardized,columns=df3.columns)
df_standardized
# Out:
#            size  total_sqft      bath     price
# 0     -0.648655   -0.624815 -0.443440 -0.904015
# 1      0.823560    0.374710 -0.443440 -0.321678
# 2      0.823560    0.585547  1.049094  0.516399
# 3     -0.648655   -0.249993 -0.443440 -0.601038
# 4     -0.648655   -0.328081 -0.443440 -0.931189
# ...         ...         ...       ...       ...
# 10567  0.823560    0.986398  1.049094  0.443512
# 10568 -0.648655   -0.640433 -0.443440 -0.557610
# 10569 -0.648655   -0.088612 -0.443440 -0.702623
# 10570  0.823560    1.090516  1.049094  0.948136
# 10571 -0.648655   -0.403566 -0.443440 -0.372471
#
# [10572 rows x 4 columns]

# %%
#create subplot
plt.figure(figsize=(12,10))

#original and scaled data histogram for each feature
plt.subplot(5,2,1)
sns.histplot(df3['size'],kde=True)
plt.title('original: size')

plt.subplot(5,2,2)
sns.histplot(df_standardized['size'],kde=True)
plt.title('scaled: size')

plt.subplot(5,2,3)
sns.histplot(df3['total_sqft'],kde=True)
plt.title('original: total_sqft')

plt.subplot(5,2,4)
sns.histplot(df_standardized['total_sqft'],kde=True)
plt.title('scaled: total_sqft')

plt.subplot(5,2,5)
sns.histplot(df3['bath'],kde=True)
plt.title('original: bath')

plt.subplot(5,2,6)
sns.histplot(df_standardized['bath'],kde=True)
plt.title('scaled: bath')

plt.subplot(5,2,7)
sns.histplot(df3['price'],kde=True)
plt.title('original: price')

plt.subplot(5,2,8)
sns.histplot(df_standardized['price'],kde=True)
plt.title('scaled: price')
# Out:
# Text(0.5, 1.0, 'scaled: price')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.heatmap(df_standardized.corr(),annot=True,cmap="coolwarm")
plt.show()

# %%
x=df3.drop(columns=["price"])
y=df3["price"]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)

from sklearn.metrics import r2_score,mean_squared_error

#Training predictions
# y_train_pred = model.predict(x_train)
# r2_train = r2_score(y_train , y_train_pred)
# mse_train = mean_squared_error(y_train , y_train_pred)

#validation prediction
y_val_pred=model.predict(x_test)
r2_val=r2_score(y_test,y_val_pred)
mse_val=mean_squared_error(y_test,y_val_pred)


#print('R2 score (Train):"",r2_train)
print("R2 score (validation):",r2_val)
#print("MSE (train):", mse_train)
print("MSE (validation):",mse_val)
# Out:
# R2 score (validation): 0.47145887839340783
# MSE (validation): 798.5833314012077

# %% [markdown]
# #**`Dimensionality reduction`**

# %% [markdown]
# ##**`Feature extraction(PCA)`**

# %%
x=df_standardized.drop(columns=['price'])
y=df_standardized['price']

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=2)

x_pca=pca.fit_transform(x)

# %%
x_pca
# Out:
# array([[-0.98795139, -0.10089721],
#        [ 0.42908113,  0.15803315],
#        [ 1.42932302, -0.2298828 ],
#        ...,
#        [-0.69545958,  0.34847881],
#        [ 1.70477648,  0.19331597],
#        [-0.86726302,  0.08452494]])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x_pca,y,test_size=0.2,random_state=42)

# %%
print(x_test.shape)
print(x_train.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (2115, 2)
# (8457, 2)
# (2115,)
# (8457,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error

#Training predictions
# y_train_pred = model.predict(x_train)
# r2_train = r2_score(y_train , y_train_pred)
# mse_train = mean_squared_error(y_train , y_train_pred)

#validation prediction
y_val_pred=model.predict(x_test)
r2_val=r2_score(y_test,y_val_pred)
mse_val=mean_squared_error(y_test,y_val_pred)


#print('R2 score (Train):"",r2_train)
print("R2 score (validation):",r2_val)
#print("MSE (train):", mse_train)
print("MSE (validation):",mse_val)
# Out:
# R2 score (validation): 0.46684598589838777
# MSE (validation): 0.5195588236887525

# %% [markdown]
# #**`EVALUTION METRICS IN REGRESSION`**

# %% [markdown]
# ##**`MAE`**

# %%
# MAE (mean absolute error)

from sklearn.metrics import mean_absolute_error

mae=mean_absolute_error(y_test,y_val_pred)
print('MAE:',mae)
# Out:
# MAE: 0.5147636451953903

# %% [markdown]
# ##**`MSE`**

# %%
# MSE (mean squared error)

from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test,y_val_pred)
print('MSE:',mse)
# Out:
# MSE: 0.5195588236887525

# %% [markdown]
# ##**`RMSE`**

# %%
#RMSE (robot mean squared error)
rmse=np.sqrt(mse)
print("RMSE: ",rmse)
# Out:
# RMSE:  0.7208042894494681

# %% [markdown]
# ##**`R2 SCORE`**

# %%
#R2 SCORE (R-SQUARED)
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_val_pred)
print('R2 score: ',r2)
# Out:
# R2 score:  0.46684598589838777
